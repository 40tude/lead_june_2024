# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv("./data/20240709_cooked_covid.csv")
display(df)
# Out:
#             date  incid_hosp
# 0     2020-03-18         NaN
# 1     2020-03-19   22.069307
# 2     2020-03-20   12.435644
# 3     2020-03-21   15.247525
# 4     2020-03-22   15.188119
# ...          ...         ...
# 1195  2023-06-26    0.821782
# 1196  2023-06-27    0.792079
# 1197  2023-06-28    0.623762
# 1198  2023-06-29    0.564356
# 1199  2023-06-30    0.643564
#
# [1200 rows x 2 columns]

# %%
fig = px.line(df, x='date', y="incid_hosp")
fig.show()
